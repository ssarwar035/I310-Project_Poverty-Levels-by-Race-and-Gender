# %% [markdown]
# <a href="https://colab.research.google.com/github/ssarwar035/I310-Project_Poverty-Levels-by-Race-and-Gender/blob/main/I310D_Final_Project_Black_Men.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **OVERALL METHOD AND ALLOCATION**
#
# Annual Poverty Level Wages - Chinmayee
#
# Black women black men - Simaat
#
# White women white men - Nithya
#
# Hispanic women hispanic men - Sreehana
#
# create 7 predictive models
#
# 1973-2000 for training the dataset
# 2000-2020 for predicted model

# %%
import pandas as pd
import numpy as np
import seaborn as sns

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # **CLEANING**

# %%
df = pd.read_csv('poverty_level_wages.csv')

# sort in ascending order by year
print(type(df.year[0]))
df.sort_values(by='year')
# Out:
# <class 'numpy.int64'>
#     year  annual_poverty-level_wage  hourly_poverty-level_wage  \
# 49  1973                       4701                       2.26
# 48  1974                       5158                       2.48
# 47  1975                       5595                       2.69
# 46  1976                       5914                       2.84
# 45  1977                       6284                       3.02
# 44  1978                       6718                       3.23
# 43  1979                       7360                       3.54
# 42  1980                       8181                       3.93
# 41  1981                       8956                       4.31
# 40  1982                       9499                       4.57
# 39  1983                       9901                       4.76
# 38  1984                      10317                       4.96
# 37  1985                      10670                       5.13
# 36  1986                      10858                       5.22
# 35  1987                      11223                       5.40
# 34  1988                      11629                       5.59
# 33  1989                      12143                       5.84
# 32  1990                      12740                       6.12
# 31  1991                      13208                       6.35
# 30  1992                      13536                       6.51
# 29  1993                      13874                       6.67
# 28  1994                      14167                       6.81
# 27  1995                      14500                       6.97
# 26  1996                      14893                       7.16
# 25  1997                      15214                       7.31
# 24  1998                      15413                       7.41
# 23  1999                      15749                       7.57
# 22  2000                      16286                       7.83
# 21  2001                      16744                       8.05
# 20  2002                      17014                       8.18
# 19  2003                      17400                       8.37
# 18  2004                      17867                       8.59
# 17  2005                      18470                       8.88
# 16  2006                      19074                       9.17
# 15  2007                      19614                       9.43
# 14  2008                      20364                       9.79
# 13  2009                      20293                       9.76
# 12  2010                      20634                       9.92
# 11  2011                      21278                      10.23
# 10  2012                      21715                      10.44
# 9   2013                      22048                      10.60
# 8   2014                      22422                      10.78
# 7   2015                      22464                      10.80
# 6   2016                      22755                      10.94
# 5   2017                      23244                      11.18
# 4   2018                      23809                      11.45
# 3   2019                      24242                      11.65
# 2   2020                      24544                      11.80
# 1   2021                      25688                      12.35
# 0   2022                      27733                      13.33
#
#     0-75%_of_poverty_wages  75-100%_of_poverty_wages  \
# 49                     9.3                      16.3
# 48                     7.5                      16.8
# 47                    10.2                      15.7
# 46                     7.1                      18.0
# 45                     6.2                      20.7
# 44                     5.4                      20.6
# 43                     5.1                      20.7
# 42                     4.6                      21.1
# 41                     5.3                      22.5
# 40                    10.6                      17.6
# 39                    13.0                      15.1
# 38                    13.1                      13.4
# 37                    13.4                      16.4
# 36                    12.7                      15.6
# 35                    14.8                      12.8
# 34                    13.3                      14.3
# 33                    13.1                      14.0
# 32                    13.0                      15.4
# 31                    12.2                      16.0
# 30                    11.4                      17.5
# 29                    14.8                      13.3
# 28                    14.3                      13.3
# 27                    13.1                      13.6
# 26                    12.9                      15.6
# 25                    10.8                      16.3
# 24                     9.3                      15.3
# 23                     7.5                      16.5
# 22                     7.2                      14.8
# 21                     7.8                      15.0
# 20                     7.0                      14.5
# 19                     7.1                      13.8
# 18                     6.7                      14.6
# 17                     7.3                      13.9
# 16                     7.1                      15.1
# 15                     7.5                      13.7
# 14                     7.0                      14.0
# 13                     6.3                      14.2
# 12                     5.6                      14.9
# 11                     6.7                      18.1
# 10                     6.9                      18.0
# 9                      6.4                      18.6
# 8                      8.2                      16.2
# 7                      6.7                      16.3
# 6                      5.6                      15.2
# 5                      5.1                      15.3
# 4                      5.0                      13.0
# 3                      4.4                      11.3
# 2                      3.4                       8.6
# 1                      3.8                       9.1
# 0                      4.7                       7.5
#
#     share_below_poverty_wages  100-125%_of_poverty_wages  \
# 49                       25.6                       12.7
# 48                       24.3                       15.2
# 47                       25.9                       13.9
# 46                       25.1                       15.2
# 45                       26.9                       13.6
# 44                       26.0                       15.4
# 43                       25.8                       13.6
# 42                       25.7                       13.8
# 41                       27.8                       14.4
# 40                       28.3                       13.5
# 39                       28.1                       13.2
# 38                       26.5                       15.6
# 37                       29.8                       12.3
# 36                       28.3                       12.9
# 35                       27.6                       12.4
# 34                       27.6                       11.4
# 33                       27.1                       13.5
# 32                       28.4                       13.2
# 31                       28.2                       12.2
# 30                       28.9                       13.3
# 29                       28.1                       13.5
# 28                       27.6                       14.6
# 27                       26.6                       14.9
# 26                       28.5                       12.3
# 25                       27.2                       14.0
# 24                       24.5                       14.3
# 23                       23.9                       12.7
# 22                       22.1                       13.7
# 21                       22.9                       14.5
# 20                       21.5                       14.3
# 19                       20.9                       14.1
# 18                       21.3                       13.7
# 17                       21.2                       15.4
# 16                       22.3                       12.9
# 15                       21.3                       13.4
# 14                       21.0                       14.8
# 13                       20.4                       14.6
# 12                       20.5                       14.8
# 11                       24.8                       11.6
# 10                       24.9                       12.9
# 9                        25.0                       12.2
# 8                        24.4                       12.3
# 7                        23.0                       13.0
# 6                        20.8                       13.2
# 5                        20.4                       12.0
# 4                        18.1                       14.2
# 3                        15.7                       14.2
# 2                        12.0                       13.0
# 1                        12.9                       15.0
# 0                        12.2                       15.2
#
#     125-200%_of_poverty_wages  200-300%_of_poverty_wages  \
# 49                       32.9                       19.8
# 48                       31.0                       20.6
# 47                       32.0                       19.5
# 46                       31.2                       19.6
# 45                       30.3                       20.5
# 44                       29.6                       19.9
# 43                       31.1                       20.7
# 42                       31.8                       19.9
# 41                       29.1                       20.5
# 40                       29.4                       19.7
# 39                       29.3                       19.9
# 38                       27.5                       20.4
# 37                       29.2                       19.2
# 36                       28.4                       19.9
# 35                       29.2                       20.0
# 34                       30.4                       19.2
# 33                       28.9                       19.9
# 32                       28.6                       19.1
# 31                       30.2                       18.4
# 30                       28.7                       17.8
# 29                       28.5                       19.6
# 28                       27.3                       18.9
# 27                       27.8                       18.9
# 26                       28.6                       18.7
# 25                       27.9                       18.5
# 24                       28.0                       19.9
# 23                       30.4                       18.6
# 22                       30.4                       19.1
# 21                       28.1                       19.7
# 20                       28.6                       19.7
# 19                       28.5                       20.8
# 18                       29.0                       19.9
# 17                       27.8                       19.8
# 16                       29.5                       19.2
# 15                       29.0                       19.5
# 14                       28.2                       19.2
# 13                       27.8                       19.7
# 12                       27.5                       19.6
# 11                       28.4                       18.3
# 10                       26.7                       18.8
# 9                        27.5                       18.0
# 8                        27.7                       18.7
# 7                        27.1                       18.7
# 6                        28.4                       18.8
# 5                        29.8                       18.4
# 4                        29.3                       19.1
# 3                        31.2                       18.7
# 2                        31.5                       20.8
# 1                        30.3                       20.4
# 0                        32.7                       19.5
#
#     300%+_of_poverty_wages  ...  women_300%+_of_poverty_wages  \
# 49                     9.0  ...                           2.4
# 48                     8.9  ...                           2.3
# 47                     8.7  ...                           2.5
# 46                     9.0  ...                           2.8
# 45                     8.7  ...                           2.4
# 44                     9.1  ...                           2.3
# 43                     8.9  ...                           2.4
# 42                     8.8  ...                           2.4
# 41                     8.2  ...                           2.4
# 40                     9.1  ...                           2.8
# 39                     9.4  ...                           3.1
# 38                    10.1  ...                           3.6
# 37                     9.5  ...                           3.5
# 36                    10.4  ...                           4.1
# 35                    10.8  ...                           4.7
# 34                    11.4  ...                           5.3
# 33                    10.6  ...                           5.2
# 32                    10.8  ...                           5.6
# 31                    11.0  ...                           6.1
# 30                    11.3  ...                           6.7
# 29                    10.4  ...                           6.3
# 28                    11.6  ...                           7.4
# 27                    11.8  ...                           7.5
# 26                    11.9  ...                           7.6
# 25                    12.5  ...                           8.1
# 24                    13.2  ...                           8.7
# 23                    14.3  ...                           9.6
# 22                    14.7  ...                           9.9
# 21                    14.9  ...                          10.1
# 20                    15.9  ...                          11.1
# 19                    15.6  ...                          11.0
# 18                    16.0  ...                          11.5
# 17                    15.8  ...                          11.6
# 16                    16.1  ...                          11.8
# 15                    16.8  ...                          12.5
# 14                    16.7  ...                          12.4
# 13                    17.5  ...                          13.0
# 12                    17.6  ...                          13.6
# 11                    16.8  ...                          12.9
# 10                    16.7  ...                          12.5
# 9                     17.3  ...                          13.2
# 8                     16.9  ...                          13.2
# 7                     18.2  ...                          14.2
# 6                     18.9  ...                          14.9
# 5                     19.4  ...                          15.1
# 4                     19.4  ...                          15.2
# 3                     20.3  ...                          16.0
# 2                     22.6  ...                          18.1
# 1                     21.5  ...                          17.4
# 0                     20.4  ...                          16.7
#
#     white_share_below_poverty_wages  white_men_share_below_poverty_wages  \
# 49                             23.8                                 13.7
# 48                             22.7                                 12.8
# 47                             24.2                                 14.4
# 46                             23.6                                 14.1
# 45                             25.4                                 15.5
# 44                             24.5                                 14.7
# 43                             24.3                                 14.3
# 42                             24.2                                 14.4
# 41                             26.2                                 16.4
# 40                             26.6                                 17.3
# 39                             26.5                                 17.8
# 38                             24.7                                 16.4
# 37                             27.7                                 19.1
# 36                             26.2                                 18.3
# 35                             25.3                                 17.6
# 34                             25.4                                 17.9
# 33                             24.7                                 17.4
# 32                             25.5                                 18.5
# 31                             25.4                                 18.6
# 30                             25.9                                 19.7
# 29                             25.2                                 19.3
# 28                             24.7                                 18.7
# 27                             23.6                                 17.3
# 26                             25.0                                 18.8
# 25                             23.6                                 17.5
# 24                             21.4                                 15.8
# 23                             20.7                                 15.3
# 22                             19.0                                 13.8
# 21                             19.5                                 14.5
# 20                             18.3                                 13.8
# 19                             17.9                                 13.5
# 18                             18.3                                 14.0
# 17                             18.0                                 13.6
# 16                             19.0                                 14.7
# 15                             18.1                                 13.5
# 14                             18.0                                 13.5
# 13                             17.5                                 13.5
# 12                             17.5                                 13.6
# 11                             20.9                                 17.1
# 10                             20.8                                 16.6
# 9                              20.8                                 16.9
# 8                              20.2                                 16.0
# 7                              18.9                                 15.2
# 6                              17.3                                 14.0
# 5                              16.8                                 13.4
# 4                              15.0                                 11.6
# 3                              13.4                                 10.5
# 2                              10.4                                  7.9
# 1                              11.1                                  8.7
# 0                              10.7                                  8.1
#
#     white_women_share_below_poverty_wages  black_share_below_poverty_wages  \
# 49                                   38.5                             37.3
# 48                                   37.0                             34.6
# 47                                   38.2                             36.7
# 46                                   36.7                             34.8
# 45                                   38.7                             36.7
# 44                                   37.5                             35.5
# 43                                   37.3                             33.7
# 42                                   36.5                             34.1
# 41                                   38.4                             35.7
# 40                                   37.8                             36.9
# 39                                   36.8                             36.7
# 38                                   34.7                             35.0
# 37                                   37.8                             39.4
# 36                                   35.4                             37.0
# 35                                   34.2                             36.4
# 34                                   33.9                             35.8
# 33                                   32.8                             35.7
# 32                                   33.4                             37.0
# 31                                   32.7                             36.6
# 30                                   32.7                             37.4
# 29                                   31.7                             36.1
# 28                                   31.2                             35.9
# 27                                   30.6                             33.6
# 26                                   31.7                             37.9
# 25                                   30.2                             35.4
# 24                                   27.4                             31.3
# 23                                   26.7                             30.0
# 22                                   24.5                             26.7
# 21                                   24.9                             28.8
# 20                                   23.2                             26.6
# 19                                   22.6                             25.3
# 18                                   22.8                             25.9
# 17                                   22.7                             27.1
# 16                                   23.7                             27.8
# 15                                   23.1                             26.3
# 14                                   22.6                             27.6
# 13                                   21.7                             25.7
# 12                                   21.6                             25.0
# 11                                   24.9                             31.6
# 10                                   25.4                             31.0
# 9                                    24.9                             31.9
# 8                                    24.6                             32.4
# 7                                    22.9                             31.8
# 6                                    20.8                             28.8
# 5                                    20.5                             29.1
# 4                                    18.7                             26.0
# 3                                    16.6                             22.3
# 2                                    13.1                             18.1
# 1                                    13.8                             18.0
# 0                                    13.5                             16.2
#
#     black_men_share_below_poverty_wages  \
# 49                                 25.3
# 48                                 22.8
# 47                                 25.1
# 46                                 23.8
# 45                                 28.0
# 44                                 25.2
# 43                                 25.1
# 42                                 25.3
# 41                                 26.8
# 40                                 29.3
# 39                                 30.7
# 38                                 28.0
# 37                                 33.6
# 36                                 31.1
# 35                                 30.5
# 34                                 29.9
# 33                                 30.5
# 32                                 32.0
# 31                                 32.6
# 30                                 33.8
# 29                                 32.9
# 28                                 31.1
# 27                                 28.8
# 26                                 33.5
# 25                                 30.3
# 24                                 25.7
# 23                                 24.3
# 22                                 22.7
# 21                                 24.1
# 20                                 22.5
# 19                                 20.9
# 18                                 21.7
# 17                                 23.3
# 16                                 24.1
# 15                                 23.2
# 14                                 24.1
# 13                                 22.4
# 12                                 22.1
# 11                                 29.2
# 10                                 28.2
# 9                                  29.0
# 8                                  30.2
# 7                                  28.3
# 6                                  25.1
# 5                                  26.4
# 4                                  23.1
# 3                                  19.2
# 2                                  15.4
# 1                                  15.7
# 0                                  14.5
#
#     black_women_share_below_poverty_wages  hispanic_share_below_poverty_wages  \
# 49                                   50.6                                34.9
# 48                                   47.4                                33.7
# 47                                   49.1                                35.0
# 46                                   46.2                                34.8
# 45                                   45.7                                36.0
# 44                                   46.0                                32.6
# 43                                   42.9                                34.6
# 42                                   43.0                                33.6
# 41                                   44.7                                37.1
# 40                                   44.4                                37.5
# 39                                   42.8                                37.4
# 38                                   41.8                                35.9
# 37                                   44.9                                40.3
# 36                                   42.7                                39.4
# 35                                   42.1                                38.7
# 34                                   41.5                                39.1
# 33                                   40.7                                39.7
# 32                                   41.5                                42.8
# 31                                   40.3                                43.4
# 30                                   40.7                                43.7
# 29                                   39.1                                42.9
# 28                                   40.3                                42.7
# 27                                   38.0                                42.6
# 26                                   41.8                                44.8
# 25                                   39.7                                43.5
# 24                                   36.0                                38.9
# 23                                   34.7                                38.9
# 22                                   30.1                                36.4
# 21                                   32.6                                37.5
# 20                                   30.0                                34.9
# 19                                   29.0                                33.3
# 18                                   29.4                                33.7
# 17                                   30.3                                33.1
# 16                                   30.8                                34.5
# 15                                   28.9                                32.7
# 14                                   30.5                                31.3
# 13                                   28.3                                31.0
# 12                                   27.4                                31.7
# 11                                   33.6                                38.3
# 10                                   33.3                                38.3
# 9                                    34.4                                38.2
# 8                                    34.3                                36.2
# 7                                    34.8                                33.5
# 6                                    32.0                                29.2
# 5                                    31.4                                28.5
# 4                                    28.5                                24.3
# 3                                    24.9                                19.7
# 2                                    20.5                                14.9
# 1                                    19.9                                16.8
# 0                                    17.7                                15.4
#
#     hispanic_men_share_below_poverty_wages  \
# 49                                    27.1
# 48                                    24.5
# 47                                    27.3
# 46                                    27.2
# 45                                    25.6
# 44                                    23.8
# 43                                    25.1
# 42                                    25.3
# 41                                    29.1
# 40                                    30.6
# 39                                    30.2
# 38                                    29.2
# 37                                    34.8
# 36                                    33.9
# 35                                    33.7
# 34                                    33.8
# 33                                    35.4
# 32                                    39.2
# 31                                    40.0
# 30                                    40.9
# 29                                    39.7
# 28                                    39.3
# 27                                    39.1
# 26                                    41.4
# 25                                    39.3
# 24                                    34.2
# 23                                    33.9
# 22                                    31.9
# 21                                    33.7
# 20                                    30.3
# 19                                    29.3
# 18                                    29.6
# 17                                    28.8
# 16                                    29.8
# 15                                    28.0
# 14                                    26.4
# 13                                    26.2
# 12                                    27.4
# 11                                    35.5
# 10                                    34.1
# 9                                     34.8
# 8                                     31.7
# 7                                     29.1
# 6                                     24.7
# 5                                     23.7
# 4                                     19.3
# 3                                     15.8
# 2                                     12.0
# 1                                     14.2
# 0                                     12.3
#
#     hispanic_women_share_below_poverty_wages
# 49                                      48.2
# 48                                      49.7
# 47                                      47.5
# 46                                      46.3
# 45                                      52.8
# 44                                      46.5
# 43                                      49.6
# 42                                      46.5
# 41                                      49.4
# 40                                      47.7
# 39                                      47.7
# 38                                      45.1
# 37                                      48.8
# 36                                      47.7
# 35                                      46.1
# 34                                      46.9
# 33                                      46.0
# 32                                      48.2
# 31                                      48.7
# 30                                      47.9
# 29                                      47.5
# 28                                      47.8
# 27                                      47.8
# 26                                      49.8
# 25                                      50.0
# 24                                      45.8
# 23                                      45.8
# 22                                      43.1
# 21                                      43.1
# 20                                      41.5
# 19                                      39.1
# 18                                      39.7
# 17                                      39.6
# 16                                      41.5
# 15                                      39.6
# 14                                      38.4
# 13                                      37.7
# 12                                      37.6
# 11                                      42.3
# 10                                      43.7
# 9                                       42.7
# 8                                       42.1
# 7                                       39.2
# 6                                       35.1
# 5                                       34.8
# 4                                       30.7
# 3                                       24.6
# 2                                       18.6
# 1                                       20.0
# 0                                       19.2
#
# [50 rows x 33 columns]

# %% [markdown]
# Extracting the required rows

# %%
df_filtered = df[["year", "annual_poverty-level_wage", "white_share_below_poverty_wages", "white_men_share_below_poverty_wages", "white_women_share_below_poverty_wages", "black_share_below_poverty_wages", "black_men_share_below_poverty_wages", "black_women_share_below_poverty_wages", "hispanic_share_below_poverty_wages", "hispanic_men_share_below_poverty_wages", "hispanic_women_share_below_poverty_wages"]]
df_filtered.sort_values(by='year')
# Out:
#     year  annual_poverty-level_wage  white_share_below_poverty_wages  \
# 49  1973                       4701                             23.8
# 48  1974                       5158                             22.7
# 47  1975                       5595                             24.2
# 46  1976                       5914                             23.6
# 45  1977                       6284                             25.4
# 44  1978                       6718                             24.5
# 43  1979                       7360                             24.3
# 42  1980                       8181                             24.2
# 41  1981                       8956                             26.2
# 40  1982                       9499                             26.6
# 39  1983                       9901                             26.5
# 38  1984                      10317                             24.7
# 37  1985                      10670                             27.7
# 36  1986                      10858                             26.2
# 35  1987                      11223                             25.3
# 34  1988                      11629                             25.4
# 33  1989                      12143                             24.7
# 32  1990                      12740                             25.5
# 31  1991                      13208                             25.4
# 30  1992                      13536                             25.9
# 29  1993                      13874                             25.2
# 28  1994                      14167                             24.7
# 27  1995                      14500                             23.6
# 26  1996                      14893                             25.0
# 25  1997                      15214                             23.6
# 24  1998                      15413                             21.4
# 23  1999                      15749                             20.7
# 22  2000                      16286                             19.0
# 21  2001                      16744                             19.5
# 20  2002                      17014                             18.3
# 19  2003                      17400                             17.9
# 18  2004                      17867                             18.3
# 17  2005                      18470                             18.0
# 16  2006                      19074                             19.0
# 15  2007                      19614                             18.1
# 14  2008                      20364                             18.0
# 13  2009                      20293                             17.5
# 12  2010                      20634                             17.5
# 11  2011                      21278                             20.9
# 10  2012                      21715                             20.8
# 9   2013                      22048                             20.8
# 8   2014                      22422                             20.2
# 7   2015                      22464                             18.9
# 6   2016                      22755                             17.3
# 5   2017                      23244                             16.8
# 4   2018                      23809                             15.0
# 3   2019                      24242                             13.4
# 2   2020                      24544                             10.4
# 1   2021                      25688                             11.1
# 0   2022                      27733                             10.7
#
#     white_men_share_below_poverty_wages  \
# 49                                 13.7
# 48                                 12.8
# 47                                 14.4
# 46                                 14.1
# 45                                 15.5
# 44                                 14.7
# 43                                 14.3
# 42                                 14.4
# 41                                 16.4
# 40                                 17.3
# 39                                 17.8
# 38                                 16.4
# 37                                 19.1
# 36                                 18.3
# 35                                 17.6
# 34                                 17.9
# 33                                 17.4
# 32                                 18.5
# 31                                 18.6
# 30                                 19.7
# 29                                 19.3
# 28                                 18.7
# 27                                 17.3
# 26                                 18.8
# 25                                 17.5
# 24                                 15.8
# 23                                 15.3
# 22                                 13.8
# 21                                 14.5
# 20                                 13.8
# 19                                 13.5
# 18                                 14.0
# 17                                 13.6
# 16                                 14.7
# 15                                 13.5
# 14                                 13.5
# 13                                 13.5
# 12                                 13.6
# 11                                 17.1
# 10                                 16.6
# 9                                  16.9
# 8                                  16.0
# 7                                  15.2
# 6                                  14.0
# 5                                  13.4
# 4                                  11.6
# 3                                  10.5
# 2                                   7.9
# 1                                   8.7
# 0                                   8.1
#
#     white_women_share_below_poverty_wages  black_share_below_poverty_wages  \
# 49                                   38.5                             37.3
# 48                                   37.0                             34.6
# 47                                   38.2                             36.7
# 46                                   36.7                             34.8
# 45                                   38.7                             36.7
# 44                                   37.5                             35.5
# 43                                   37.3                             33.7
# 42                                   36.5                             34.1
# 41                                   38.4                             35.7
# 40                                   37.8                             36.9
# 39                                   36.8                             36.7
# 38                                   34.7                             35.0
# 37                                   37.8                             39.4
# 36                                   35.4                             37.0
# 35                                   34.2                             36.4
# 34                                   33.9                             35.8
# 33                                   32.8                             35.7
# 32                                   33.4                             37.0
# 31                                   32.7                             36.6
# 30                                   32.7                             37.4
# 29                                   31.7                             36.1
# 28                                   31.2                             35.9
# 27                                   30.6                             33.6
# 26                                   31.7                             37.9
# 25                                   30.2                             35.4
# 24                                   27.4                             31.3
# 23                                   26.7                             30.0
# 22                                   24.5                             26.7
# 21                                   24.9                             28.8
# 20                                   23.2                             26.6
# 19                                   22.6                             25.3
# 18                                   22.8                             25.9
# 17                                   22.7                             27.1
# 16                                   23.7                             27.8
# 15                                   23.1                             26.3
# 14                                   22.6                             27.6
# 13                                   21.7                             25.7
# 12                                   21.6                             25.0
# 11                                   24.9                             31.6
# 10                                   25.4                             31.0
# 9                                    24.9                             31.9
# 8                                    24.6                             32.4
# 7                                    22.9                             31.8
# 6                                    20.8                             28.8
# 5                                    20.5                             29.1
# 4                                    18.7                             26.0
# 3                                    16.6                             22.3
# 2                                    13.1                             18.1
# 1                                    13.8                             18.0
# 0                                    13.5                             16.2
#
#     black_men_share_below_poverty_wages  \
# 49                                 25.3
# 48                                 22.8
# 47                                 25.1
# 46                                 23.8
# 45                                 28.0
# 44                                 25.2
# 43                                 25.1
# 42                                 25.3
# 41                                 26.8
# 40                                 29.3
# 39                                 30.7
# 38                                 28.0
# 37                                 33.6
# 36                                 31.1
# 35                                 30.5
# 34                                 29.9
# 33                                 30.5
# 32                                 32.0
# 31                                 32.6
# 30                                 33.8
# 29                                 32.9
# 28                                 31.1
# 27                                 28.8
# 26                                 33.5
# 25                                 30.3
# 24                                 25.7
# 23                                 24.3
# 22                                 22.7
# 21                                 24.1
# 20                                 22.5
# 19                                 20.9
# 18                                 21.7
# 17                                 23.3
# 16                                 24.1
# 15                                 23.2
# 14                                 24.1
# 13                                 22.4
# 12                                 22.1
# 11                                 29.2
# 10                                 28.2
# 9                                  29.0
# 8                                  30.2
# 7                                  28.3
# 6                                  25.1
# 5                                  26.4
# 4                                  23.1
# 3                                  19.2
# 2                                  15.4
# 1                                  15.7
# 0                                  14.5
#
#     black_women_share_below_poverty_wages  hispanic_share_below_poverty_wages  \
# 49                                   50.6                                34.9
# 48                                   47.4                                33.7
# 47                                   49.1                                35.0
# 46                                   46.2                                34.8
# 45                                   45.7                                36.0
# 44                                   46.0                                32.6
# 43                                   42.9                                34.6
# 42                                   43.0                                33.6
# 41                                   44.7                                37.1
# 40                                   44.4                                37.5
# 39                                   42.8                                37.4
# 38                                   41.8                                35.9
# 37                                   44.9                                40.3
# 36                                   42.7                                39.4
# 35                                   42.1                                38.7
# 34                                   41.5                                39.1
# 33                                   40.7                                39.7
# 32                                   41.5                                42.8
# 31                                   40.3                                43.4
# 30                                   40.7                                43.7
# 29                                   39.1                                42.9
# 28                                   40.3                                42.7
# 27                                   38.0                                42.6
# 26                                   41.8                                44.8
# 25                                   39.7                                43.5
# 24                                   36.0                                38.9
# 23                                   34.7                                38.9
# 22                                   30.1                                36.4
# 21                                   32.6                                37.5
# 20                                   30.0                                34.9
# 19                                   29.0                                33.3
# 18                                   29.4                                33.7
# 17                                   30.3                                33.1
# 16                                   30.8                                34.5
# 15                                   28.9                                32.7
# 14                                   30.5                                31.3
# 13                                   28.3                                31.0
# 12                                   27.4                                31.7
# 11                                   33.6                                38.3
# 10                                   33.3                                38.3
# 9                                    34.4                                38.2
# 8                                    34.3                                36.2
# 7                                    34.8                                33.5
# 6                                    32.0                                29.2
# 5                                    31.4                                28.5
# 4                                    28.5                                24.3
# 3                                    24.9                                19.7
# 2                                    20.5                                14.9
# 1                                    19.9                                16.8
# 0                                    17.7                                15.4
#
#     hispanic_men_share_below_poverty_wages  \
# 49                                    27.1
# 48                                    24.5
# 47                                    27.3
# 46                                    27.2
# 45                                    25.6
# 44                                    23.8
# 43                                    25.1
# 42                                    25.3
# 41                                    29.1
# 40                                    30.6
# 39                                    30.2
# 38                                    29.2
# 37                                    34.8
# 36                                    33.9
# 35                                    33.7
# 34                                    33.8
# 33                                    35.4
# 32                                    39.2
# 31                                    40.0
# 30                                    40.9
# 29                                    39.7
# 28                                    39.3
# 27                                    39.1
# 26                                    41.4
# 25                                    39.3
# 24                                    34.2
# 23                                    33.9
# 22                                    31.9
# 21                                    33.7
# 20                                    30.3
# 19                                    29.3
# 18                                    29.6
# 17                                    28.8
# 16                                    29.8
# 15                                    28.0
# 14                                    26.4
# 13                                    26.2
# 12                                    27.4
# 11                                    35.5
# 10                                    34.1
# 9                                     34.8
# 8                                     31.7
# 7                                     29.1
# 6                                     24.7
# 5                                     23.7
# 4                                     19.3
# 3                                     15.8
# 2                                     12.0
# 1                                     14.2
# 0                                     12.3
#
#     hispanic_women_share_below_poverty_wages
# 49                                      48.2
# 48                                      49.7
# 47                                      47.5
# 46                                      46.3
# 45                                      52.8
# 44                                      46.5
# 43                                      49.6
# 42                                      46.5
# 41                                      49.4
# 40                                      47.7
# 39                                      47.7
# 38                                      45.1
# 37                                      48.8
# 36                                      47.7
# 35                                      46.1
# 34                                      46.9
# 33                                      46.0
# 32                                      48.2
# 31                                      48.7
# 30                                      47.9
# 29                                      47.5
# 28                                      47.8
# 27                                      47.8
# 26                                      49.8
# 25                                      50.0
# 24                                      45.8
# 23                                      45.8
# 22                                      43.1
# 21                                      43.1
# 20                                      41.5
# 19                                      39.1
# 18                                      39.7
# 17                                      39.6
# 16                                      41.5
# 15                                      39.6
# 14                                      38.4
# 13                                      37.7
# 12                                      37.6
# 11                                      42.3
# 10                                      43.7
# 9                                       42.7
# 8                                       42.1
# 7                                       39.2
# 6                                       35.1
# 5                                       34.8
# 4                                       30.7
# 3                                       24.6
# 2                                       18.6
# 1                                       20.0
# 0                                       19.2

# %%
year = df["year"]
below_poverty_wage = df["annual_poverty-level_wage"]

plt.scatter(year,below_poverty_wage, marker=".")

plt.xlabel("Year (1973-2022)")
plt.ylabel("Wages of below Poverty Line in US ($)")

plt.title("Wages of indivdiuals below Poverty Line in United States (1973-2022)")
# Out:
# Text(0.5, 1.0, 'Wages of indivdiuals below Poverty Line in United States (1973-2022)')

# %% [markdown]
# # **SPLITTING DATA**

# %% [markdown]
# for the below code you should drop the column you are trying to test on
# so hispanic use "hispanic_share_below_poverty_wages" for eg.

# %%
train_data = df[(df['year'] >= 1973) & (df['year'] <= 2000)]
test_data = df[(df['year'] >= 2015) & (df['year'] <= 2020)]

X_train = train_data.drop('black_men_share_below_poverty_wages', axis=1)
y_train = train_data['black_men_share_below_poverty_wages']

X_test = test_data.drop('black_men_share_below_poverty_wages', axis=1)
y_test = test_data['black_men_share_below_poverty_wages']

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Mean Squared Error: 0.9498961871020483
# Root Mean Squared Error: 0.9746261781329538

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Assuming you have already trained the model and made predictions
y_test_pred = model.predict(X_test)

# Calculate Mean Squared Error (MSE)
test_mse = mean_squared_error(y_test, y_test_pred)

print(f'Testing MSE: {test_mse:.2f}')

test_r2 = r2_score(y_test, y_test_pred)

print(f'Testing R-squared: {test_r2:.2f}')
# Out:
# Testing MSE: 0.95
# Testing R-squared: 0.95

# %% [markdown]
# # **Range for annual_poverty-level_wage target variable**

# %% [markdown]
# for the below blocks, replace the target variable with your variable blocks

# %%
# Identify the target variable
target_variable = 'black_men_share_below_poverty_wages'

# Calculate the range of the target variable
target_range = df[target_variable].max() - df[target_variable].min()

print(f'Target Variable Range: {target_range}')
# Out:
# Target Variable Range: 19.299999999999997

# %% [markdown]
# future_data.csv is a csv file you must create yourself.
# for the years 2015-2020 --> put in EVERY column from the original poverty_level_wages.csv (all 33 columns) except for the column you put as the target variable/column you dropped

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
import math


# Load data
df = pd.read_csv("poverty_level_wages.csv")

# Split data into train/test
train = df[df['year'].between(1973, 2000)]
test = df[df['year'].between(2000, 2020)]

# Separate target from predictors
X_train = train.drop(['year', 'black_men_share_below_poverty_wages'], axis=1)
y_train = train['black_men_share_below_poverty_wages']

# Scale data
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Build model on training data
svr = SVR()
svr.fit(X_train, y_train)

# Make predictions on test data
X_test = test.drop(['year', 'black_men_share_below_poverty_wages'], axis=1)
X_test_scaled = scaler.transform(X_test)
y_pred = svr.predict(X_test_scaled)

from sklearn.metrics import mean_absolute_error, r2_score

# Get actual target values for test set
y_test = test['black_men_share_below_poverty_wages']

# Calculate MSE
mse = mean_squared_error(y_test, y_pred)

# Take square root to calculate RMSE
rmse = math.sqrt(mse)

print("Root Mean Squared Error:", rmse)
# Out:
# Root Mean Squared Error: 4.108454545530526
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R-squared:", r2)
# Out:
# R-squared: -0.3766181490898419

# %%
future_1 = pd.read_csv('future_1.csv')

# Use the trained model to make predictions
future_predictions = model.predict(future_1)

# %%
future_predictions = model.predict(future_1)

# %% [markdown]
# # **CREATE VISUALIZATIONS FOR PREDICTED VS. ACTUAL VALUES FOR ANNUAL POVERTY LEVEL WAGES FOR YEARS 2015-2020**

# %%
years = future_1['year']

# Scatter plot of Predicted and Actual Values
plt.figure(figsize=(12, 8))
plt.scatter(years, y_test, label='Actual Values', color='blue')
plt.scatter(years, y_pred, label='Predicted Values', color='red', marker='x')
plt.title('Predicted and Actual Values Over Time')
plt.xlabel('Year')
plt.ylabel('Wages Below Poverty Level')
plt.legend()
plt.show()
